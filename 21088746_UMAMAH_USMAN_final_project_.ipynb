# %% [markdown]
# <a href="https://colab.research.google.com/github/umamah333/Enhanced-MRI-Analysis-for-Brain-Tumour-Classification-using-Machine-Learning/blob/main/21088746_UMAMAH_USMAN_final_project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydot graphviz  #installing packages to use graphics in python
# !apt-get install -y graphviz # to create graphs or flowcharts
# !pip install Pillow # for image manipulation like storing images into different formats etc
# Out:
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (1.4.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (0.20.3)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from pydot) (3.1.2)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)

# %% [markdown]
# # **Libraries**

# %%
#General Libraries
#-----------------------------------------------------------------------------------
import os  # For operating system related operations such as file and directory management
import numpy as np  # For numerical operations and array manipulations
import pandas as pd  # For data manipulation and analysis
import matplotlib.pyplot as plt  # For creating static, animated, and interactive visualizations
import seaborn as sns  # For making statistical graphics in Python

#Machine Learning and Deep Learning Libraries
#-------------------------------------------------------------------------------------------------------------------------------------------------------------
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, auc  # For evaluation metrics and performance analysis
from sklearn.svm import SVC  # For Support Vector Classification
from sklearn.preprocessing import StandardScaler, label_binarize  # For data preprocessing
from sklearn.pipeline import make_pipeline  # For creating machine learning pipelines
import tensorflow as tf  # Core library for neural networks and deep learning
from tensorflow.keras.preprocessing.image import ImageDataGenerator  # For image data augmentation and preprocessing
from tensorflow.keras.models import Sequential, Model  # For building neural network models
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout  # For different layers in CNN
from tensorflow.keras.optimizers import Adam  # For optimizer algorithms in training neural networks
from tensorflow.keras.utils import to_categorical  # For converting a vector of labels to a binary matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.callbacks import EarlyStopping

#Image Processing Libraries
#---------------------------------------------------------------------------------------------------------------
from PIL import Image  # For image processing and opening images
import cv2  # For image processing and computer vision tasks
import imutils  # For image processing and computer vision convenience functions



#Utility Libraries
#-----------------------------------------------------------------------------------------------------------------
from tqdm import tqdm  # For displaying progress bars
import random  # For generating random numbers and making random choices
import shutil  # For file operations such as copying and moving files

#Visualization Libraries
#----------------------------------------------------------------------------------------------------------------------
import pydot  # For graph and network visualizations
from IPython.display import Image, display  # For displaying images in Jupyter notebooks

#Google Colab Specific
#--------------------------------------------------------------------------------------------------------------------------
from google.colab import drive  # For mounting Google Drive to access files stored in Google Drive

# %% [markdown]
# # **Dataset Unzipping and viewing the contents**
# The frist step is to load and unzip the data, and to view its contents

# %%
#mounting the google drive because dataset is loaded in the drive for easy access and
#further processing


drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#making seperate file for unzipping the contents of the dataset in the folder
# it would create a folder of the images into a seperate folder and will also keep the zipped folder in drive aswell.

# !mkdir -p "/content/drive/My Drive/brain_tumor_dataset"

# %%
#unzipping the dataset

# !unzip "/content/drive/My Drive/brain tumour dataset.zip" -d "/content/drive/My Drive/brain_tumor_dataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0712.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0713.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0714.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0715.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0716.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0717.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0718.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0719.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0720.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0721.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0722.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0723.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0724.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0725.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0726.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0727.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0728.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0729.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0730.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0731.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0732.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0733.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0734.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0735.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0736.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0737.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0738.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0739.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0740.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0741.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0742.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0743.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0744.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0745.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0746.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0747.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0748.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0749.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0750.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0751.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0752.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0753.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0754.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0755.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0756.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0757.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0758.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0759.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0760.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0761.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0762.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0763.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0764.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0765.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0766.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0767.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0768.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0769.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0770.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0771.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0772.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0773.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0774.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0775.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0776.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0777.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0778.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0779.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0780.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0781.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0782.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0783.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0784.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0785.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0786.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0787.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0788.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0789.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0790.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0791.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0792.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0793.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0794.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0795.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0796.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0797.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0798.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0799.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0800.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0801.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0802.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0803.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0804.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0805.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0806.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0807.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0808.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0809.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0810.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0811.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0812.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0813.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0814.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0815.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0816.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0817.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0818.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0819.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0820.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0821.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0822.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0823.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0824.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0825.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0826.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0827.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0828.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0829.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0830.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0831.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0832.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0833.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0834.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0835.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0836.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0837.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0838.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0839.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0840.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0841.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0842.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0843.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0844.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0845.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0846.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0847.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0848.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0849.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0850.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0851.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0852.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0853.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0854.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0855.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0856.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0857.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0858.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0859.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0860.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0861.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0862.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0863.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0864.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0865.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0866.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0867.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0868.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0869.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0870.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0871.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0872.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0873.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0874.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0875.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0876.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0877.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0878.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0879.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0880.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0881.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0882.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0883.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0884.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0885.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0886.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0887.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0888.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0889.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0890.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0891.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0892.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0893.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0894.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0895.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0896.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0897.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0898.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0899.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0900.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0901.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0902.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0903.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0904.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0905.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0906.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0907.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0908.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0909.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0910.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0911.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0912.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0913.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0914.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0915.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0916.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0917.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0918.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0919.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0920.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0921.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0922.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0923.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0924.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0925.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0926.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0927.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0928.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0929.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0930.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0931.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0932.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0933.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0934.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0935.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0936.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0937.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0938.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0939.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0940.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0941.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0942.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0943.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0944.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0945.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0946.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0947.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0948.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0949.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0950.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0951.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0952.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0953.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0954.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0955.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0956.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0957.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0958.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0959.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0960.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0961.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0962.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0963.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0964.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0965.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0966.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0967.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0968.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0969.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0970.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0971.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0972.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0973.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0974.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0975.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0976.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0977.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0978.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0979.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0980.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0981.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0982.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0983.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0984.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0985.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0986.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0987.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0988.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0989.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0990.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0991.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0992.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0993.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0994.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0995.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0996.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0997.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0998.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_0999.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1000.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1001.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1002.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1003.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1004.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1005.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1006.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1007.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1008.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1009.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1010.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1011.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1012.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1013.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1014.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1015.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1016.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1017.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1018.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1019.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1020.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1021.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1022.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1023.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1024.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1025.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1026.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1027.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1028.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1029.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1030.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1031.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1032.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1033.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1034.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1035.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1036.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1037.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1038.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1039.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1040.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1041.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1042.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1043.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1044.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1045.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1046.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1047.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1048.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1049.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1050.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1051.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1052.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1053.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1054.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1055.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1056.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1057.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1058.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1059.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1060.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1061.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1062.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1063.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1064.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1065.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1066.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1067.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1068.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1069.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1070.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1071.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1072.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1073.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1074.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1075.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1076.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1077.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1078.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1079.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1080.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1081.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1082.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1083.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1084.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1085.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1086.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1087.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1088.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1089.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1090.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1091.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1092.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1093.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1094.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1095.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1096.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1097.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1098.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1099.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1100.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1101.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1102.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1103.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1104.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1105.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1106.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1107.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1108.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1109.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1110.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1111.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1112.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1113.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1114.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1115.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1116.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1117.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1118.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1119.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1120.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1121.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1122.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1123.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1124.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1125.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1126.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1127.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1128.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1129.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1130.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1131.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1132.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1133.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1134.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1135.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1136.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1137.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1138.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1139.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1140.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1141.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1142.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1143.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1144.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1145.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1146.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1147.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1148.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1149.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1150.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1151.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1152.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1153.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1154.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1155.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1156.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1157.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1158.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1159.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1160.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1161.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1162.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1163.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1164.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1165.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1166.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1167.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1168.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1169.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1170.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1171.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1172.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1173.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1174.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1175.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1176.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1177.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1178.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1179.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1180.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1181.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1182.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1183.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1184.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1185.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1186.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1187.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1188.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1189.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1190.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1191.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1192.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1193.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1194.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1195.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1196.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1197.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1198.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1199.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1200.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1201.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1202.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1203.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1204.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1205.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1206.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1207.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1208.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1209.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1210.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1211.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1212.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1213.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1214.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1215.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1216.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1217.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1218.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1219.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1220.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1221.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1222.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1223.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1224.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1225.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1226.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1227.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1228.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1229.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1230.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1231.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1232.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1233.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1234.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1235.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1236.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1237.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1238.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1239.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1240.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1241.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1242.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/glioma/Tr-gl_1243.jpg
# ...
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1285.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1286.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1287.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1288.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1289.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1290.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1291.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1292.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1293.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1294.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1295.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1296.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1297.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1298.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1299.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1300.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1301.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1302.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1303.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1304.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1305.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1306.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1307.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1308.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1309.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1310.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1311.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1312.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1313.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1314.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1315.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1316.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1317.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1318.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1319.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1320.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1321.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1322.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1323.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1324.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1325.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1326.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1327.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1328.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1329.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1330.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1331.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1332.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1333.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1334.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1335.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1336.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1337.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1338.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1339.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1340.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1341.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1342.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1343.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1344.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1345.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1346.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1347.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1348.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1349.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1350.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1351.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1352.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1353.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1354.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1355.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1356.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1357.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1358.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1359.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1360.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1361.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1362.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1363.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1364.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1365.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1366.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1367.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1368.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1369.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1370.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1371.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1372.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1373.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1374.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1375.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1376.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1377.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1378.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1379.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1380.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1381.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1382.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1383.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1384.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1385.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1386.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1387.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1388.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1389.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1390.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1391.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1392.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1393.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1394.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1395.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1396.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1397.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1398.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1399.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1400.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1401.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1402.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1403.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1404.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1405.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1406.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1407.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1408.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1409.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1410.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1411.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1412.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1413.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1414.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1415.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1416.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1417.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1418.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1419.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1420.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1421.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1422.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1423.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1424.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1425.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1426.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1427.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1428.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1429.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1430.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1431.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1432.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1433.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1434.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1435.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1436.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1437.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1438.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1439.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1440.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1441.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1442.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1443.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1444.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1445.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1446.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1447.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1448.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1449.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1450.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1451.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1452.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1453.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1454.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1455.jpg
#   inflating: /content/drive/My Drive/brain_tumor_dataset/Training/pituitary/Tr-pi_1456.jpg

# %%
# Count the number of directories
num_dirs = !find "/content/drive/My Drive/brain_tumor_dataset" -type d | wc -l
print(f"Number of directories: {num_dirs[0]}")

# for Counting files numerically
num_files = !find "/content/drive/My Drive/brain_tumor_dataset" -type f | wc -l
print(f"Number of files: {num_files[0]}")

# Count the number of images (jpg and png)
num_images = !find "/content/drive/My Drive/brain_tumor_dataset" -type f \( -iname \*.jpg -o -iname \*.png \) | wc -l
print(f"Number of images: {num_images[0]}")
# Out:
# Number of directories: 11
# Number of files: 7023
# Number of images: 7023

# %%
# List all directories recursively

print("\nAll directories recursively:")
# !find "/content/drive/My Drive/brain_tumor_dataset" -type d
# Out:
# All directories recursively:
# /content/drive/My Drive/brain_tumor_dataset
# /content/drive/My Drive/brain_tumor_dataset/Testing
# /content/drive/My Drive/brain_tumor_dataset/Testing/glioma
# /content/drive/My Drive/brain_tumor_dataset/Testing/meningioma
# /content/drive/My Drive/brain_tumor_dataset/Testing/notumor
# /content/drive/My Drive/brain_tumor_dataset/Testing/pituitary
# /content/drive/My Drive/brain_tumor_dataset/Training
# /content/drive/My Drive/brain_tumor_dataset/Training/glioma
# /content/drive/My Drive/brain_tumor_dataset/Training/meningioma
# /content/drive/My Drive/brain_tumor_dataset/Training/notumor
# /content/drive/My Drive/brain_tumor_dataset/Training/pituitary

# %%
#making function to draw structure graph of the dataset
def gather_directory_structure(path):
    """
    Gathers the directory structure in a nested dictionary.

    Args:
        path: The path to the directory to display.

    Returns:
        A nested dictionary representing the directory structure.
    """
    structure = {}
    for item in os.listdir(path):
        full_path = os.path.join(path, item)
        if os.path.isdir(full_path):
            structure[item] = gather_directory_structure(full_path)  # Recursively gather subdirectory structure
    return structure

def add_nodes_edges(graph, structure, parent_name="root"):
    """
    Adds nodes and edges to the graph based on the directory structure.

    Args:
        graph: The pydot graph object.
        structure: The nested dictionary representing the directory structure.
        parent_name: The name of the parent node.
    """
    for key, value in structure.items():
        node_name = f"{parent_name}/{key}"  # Create a unique name for the node
        graph.add_node(pydot.Node(node_name, label=key))  # Add a node to the graph
        graph.add_edge(pydot.Edge(parent_name, node_name))  # Add an edge from the parent to the node
        if value:  # If the directory contains other directories
            add_nodes_edges(graph, value, node_name)  # Recursively add nodes and edges for subdirectories

# Replace with your actual directory path
path = "/content/drive/My Drive/brain_tumor_dataset"

structure = gather_directory_structure(path)  # Gather the directory structure into a nested dictionary

graph = pydot.Dot(graph_type='digraph', rankdir='TB')  # Create a new directed graph, TB = top to bottom layout
graph.add_node(pydot.Node("root", label=os.path.basename(path)))  # Add the root node with the directory name
add_nodes_edges(graph, structure, "root")  # Add nodes and edges based on the directory structure

# Save the graph to a file
graph.write_png('directory_tree.png')  # Save the graph as a PNG image

# Display the graph in Google Colab
display(Image(filename='directory_tree.png'))  # Display the saved PNG image

# %% [markdown]
# # **Exploring the Data Structures**

# %%
# Defines the base directory where the dataset is stored
base_dir = "/content/drive/My Drive/brain_tumor_dataset"

# Define the paths for the training and testing directories
train_dir = os.path.join(base_dir, 'Training')
test_dir = os.path.join(base_dir, 'Testing')

# List all categories (subdirectories) in the training and testing directories
train_categories = os.listdir(train_dir)
test_categories = os.listdir(test_dir)

# Print the names of the categories in the training and testing datasets
print("Training categories:", train_categories)
print("Testing categories:", test_categories)

# For each category in the training set, print the number of images it contains
for category in train_categories:
    print(f"{category} has {len(os.listdir(os.path.join(train_dir, category)))} images in the training set")

# For each category in the testing set, print the number of images it contains
for category in test_categories:
    print(f"{category} has {len(os.listdir(os.path.join(test_dir, category)))} images in the testing set")
# Out:
# Training categories: ['glioma', 'meningioma', 'notumor', 'pituitary']
# Testing categories: ['glioma', 'meningioma', 'notumor', 'pituitary']
# glioma has 1321 images in the training set
# meningioma has 1339 images in the training set
# notumor has 1595 images in the training set
# pituitary has 1457 images in the training set
# glioma has 300 images in the testing set
# meningioma has 306 images in the testing set
# notumor has 405 images in the testing set
# pituitary has 300 images in the testing set

# %%
from PIL import Image  # Correctly import Image from PIL

def plot_sample_images(base_dir, categories, n=5):
    """
    Plots sample images from each category in the specified base directory and prints their sizes.

    Parameters:
    base_dir (str): The base directory containing category folders.
    categories (list of str): List of category names (subdirectory names).
    n (int): Number of sample images to display from each category. Default is 5.

    The function will create a plot with sample images from each category for visualization and print their sizes.
    """
    # Set up the figure with a specified size
    plt.figure(figsize=(15, 10))

    # Loops over each category
    for i, category in enumerate(categories):
        # Get the path to the current category folder
        folder_path = os.path.join(base_dir, category)

        # Loops over the first 'n' images in the current category folder
        for j, img_name in enumerate(os.listdir(folder_path)[:n]):
            # Get the path to the current image
            img_path = os.path.join(folder_path, img_name)

            # Opens the image
            img = Image.open(img_path)

            # Creates a subplot in the current figure
            ax = plt.subplot(len(categories), n, i * n + j + 1)

            # Displays the image
            plt.imshow(img)

            # Sets the title of the subplot to the category name
            plt.title(category)

            # Removes the axis for clarity
            plt.axis('off')

            # Prints the image name and size (width, height) below the image
            ax.text(0.5, -0.1, f"{img.size}", ha='center', va='center', transform=ax.transAxes)

    # Adjusts the layout to prevent overlap
    plt.tight_layout()

    # Displays the plot
    plt.show()

plot_sample_images(train_dir, train_categories)

# %% [markdown]
# # **Data Pre-processing**

# %% [markdown]
# the images in the dataset are of different sizes ,so we will implement a technique the crop images to equal sizes for better
# performance.

# %%
def crop_img(img):
    """
    Finds the extreme points on the image and crops the rectangular region out of them.
    """
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)  # Convert the image to grayscale
    gray = cv2.GaussianBlur(gray, (3, 3), 0)  # Apply Gaussian blur to the grayscale image

    # Threshold the image, then perform erosions and dilations to remove small noise regions
    thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.erode(thresh, None, iterations=2)
    thresh = cv2.dilate(thresh, None, iterations=2)

    # Find contours in the thresholded image and grab the largest one
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    c = max(cnts, key=cv2.contourArea)

    # Find the extreme points of the largest contour
    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])
    ADD_PIXELS = 0

    # Crop the image based on the extreme points
    #array slicing method is used  to extract a region from the image based on the extreme points calculated earlier
    new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()

    return new_img  # Return the cropped image

def process_images(input_dir, output_dir, img_size=256):
    """
    Processes images in the input directory by cropping and resizing, then saves them to the output directory.

    Args:
        input_dir (str): Path to the input directory containing images.
        output_dir (str): Path to the output directory to save processed images.
        img_size (int): Desired size of the output images (default is 256x256).
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)  # Create the output directory if it doesn't exist

    for category in os.listdir(input_dir):
        category_path_input = os.path.join(input_dir, category)  # Path to the category folder in the input directory
        category_path_output = os.path.join(output_dir, category)  # Path to the category folder in the output directory

        if not os.path.exists(category_path_output):
            os.makedirs(category_path_output)  # Create the category folder in the output directory if it doesn't exist

        for img_name in os.listdir(category_path_input):
            img_path_input = os.path.join(category_path_input, img_name)  # Path to the individual image
            image = cv2.imread(img_path_input)  # Read the image
            if image is not None:
                new_img = crop_img(image)  # Crop the image
                new_img = cv2.resize(new_img, (img_size, img_size))  # Resize the image
                img_path_output = os.path.join(category_path_output, img_name)  # Path to save the processed image
                cv2.imwrite(img_path_output, new_img)  # Save the processed image

if __name__ == "__main__":
    # Define paths for the output directories for training and testing sets
    output_training_dir = "cleaned/Training"
    output_testing_dir = "cleaned/Testing"

    # Process images in the training and testing directories
    process_images(train_dir, output_training_dir)
    process_images(test_dir, output_testing_dir)

# %%
#function for viewing the dataset images after cropping the images and bringing them to the standard size
def plot_sample_images(base_dir, categories, n=5):
    """
    Plots sample images from each category in the specified base directory and prints their sizes.

    Parameters:
    base_dir (str): The base directory containing category folders.
    categories (list of str): List of category names (subdirectory names).
    n (int): Number of sample images to display from each category. Default is 5.

    The function will create a plot with sample images from each category for visualization and print their sizes.
    """
    plt.figure(figsize=(15, 10))
    for i, category in enumerate(categories):
        folder_path = os.path.join(base_dir, category)
        for j, img_name in enumerate(os.listdir(folder_path)[:n]):
            img_path = os.path.join(folder_path, img_name)
            img = Image.open(img_path)
            ax = plt.subplot(len(categories), n, i * n + j + 1)
            plt.imshow(img)
            plt.title(category)
            plt.axis('off')
            # Print image size (width, height) below the image
            ax.text(0.5, -0.1, f"{img.size}", ha='center', va='center', transform=ax.transAxes)
    plt.tight_layout()
    plt.show()


plot_sample_images(output_training_dir, train_categories)

# %% [markdown]
# # **Exploratory Data Analysis**
#
# Exploring the processed dataset through EDA is crucial to grasp its contents thoroughly. This step helps detect and address potential biases and ensures all data categories are adequately represented. By analyzing the dataset, we gain insights into class distributions, assess category balance, and identify any anomalies that could impact algorithm development. This proactive approach ensures our dataset mirrors real-world scenarios, enhancing the reliability of our machine learning models. EDA guides decisions on data preprocessing, feature engineering, and model selection, setting a strong foundation for accurate brain tumor classification and segmentation.

# %%
#class distribution plot is most important to see the dataset balance/ imbalancement

def plot_class_distribution(dataset_dir):
    """
    Plots the distribution of images across different tumor categories in the dataset.

    Parameters:
    dataset_dir (str): Directory path containing subdirectories for each tumor category.
    """
    categories = os.listdir(dataset_dir)
    category_counts = []

    for category in categories:
        category_path = os.path.join(dataset_dir, category)
        if os.path.isdir(category_path):
            num_images = len(os.listdir(category_path))
            category_counts.append((category, num_images))

    category_counts.sort(key=lambda x: x[1], reverse=True)  # Sort categories by number of images
    #where lambda is a function to extract the second element of the tuple to use for sorting

    categories, counts = zip(*category_counts)

    plt.figure(figsize=(6, 6))
    plt.bar(categories, counts, color='skyblue')
    plt.xlabel('Tumor Categories')
    plt.ylabel('Number of Images')
    plt.title('Class Distribution of Tumor Categories')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()


dataset_dir = 'cleaned/Training'
plot_class_distribution(dataset_dir)

# %%
def calculate_image_statistics(dataset_dir):
    """
    Calculates statistical metrics (mean, std deviation, range) of pixel values within images in the dataset.

    Parameters:
    dataset_dir (str): Directory path containing subdirectories for each tumor category.

    Returns:
    dict: Dictionary containing statistical metrics (mean, std_dev, min_value, max_value) for each image category.
    """
    categories = os.listdir(dataset_dir)
    category_statistics = {}

    for category in categories:
        category_path = os.path.join(dataset_dir, category)
        if os.path.isdir(category_path):
            image_stats = {
                'mean': [],
                'std_dev': [],
                'min_value': [],
                'max_value': []
            }

            for img_name in os.listdir(category_path):
                img_path = os.path.join(category_path, img_name)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Read image in grayscale mode
                if img is not None:
                    mean_value = np.mean(img)
                    std_dev_value = np.std(img)
                    min_value = np.min(img)
                    max_value = np.max(img)

                    image_stats['mean'].append(mean_value)
                    image_stats['std_dev'].append(std_dev_value)
                    image_stats['min_value'].append(min_value)
                    image_stats['max_value'].append(max_value)

            category_statistics[category] = {
                'mean': np.mean(image_stats['mean']),
                'std_dev': np.mean(image_stats['std_dev']),
                'min_value': np.min(image_stats['min_value']),
                'max_value': np.max(image_stats['max_value'])
            }

    return category_statistics

def plot_statistics(stats):
    """
    Plot graphical representation of image statistics.

    Parameters:
    stats (dict): Dictionary containing statistical metrics for each image category.
    """
    categories = list(stats.keys())
    mean_values = [stats[cat]['mean'] for cat in categories]
    std_dev_values = [stats[cat]['std_dev'] for cat in categories]
    min_values = [stats[cat]['min_value'] for cat in categories]
    max_values = [stats[cat]['max_value'] for cat in categories]

    # Debug: Print the calculated minimum values
    print("Minimum values:", min_values)

    plt.figure(figsize=(12, 8))

    plt.subplot(2, 2, 1)
    plt.bar(categories, mean_values, color='skyblue')
    plt.xlabel('Tumor Categories')
    plt.ylabel('Mean Pixel Value')
    plt.title('Mean Pixel Value Across Tumor Categories')
    plt.xticks(rotation=45)

    plt.subplot(2, 2, 2)
    plt.bar(categories, std_dev_values, color='lightgreen')
    plt.xlabel('Tumor Categories')
    plt.ylabel('Standard Deviation of Pixel Values')
    plt.title('Standard Deviation Across Tumor Categories')
    plt.xticks(rotation=45)

    plt.subplot(2, 2, 3)
    min_values = [v + 1 for v in min_values]  # Add 1 to all min values for better visualization
    plt.bar(categories, min_values, color='pink')
    plt.xlabel('Tumor Categories')
    plt.ylabel('Minimum Pixel Value')
    plt.title('Minimum Pixel Value Across Tumor Categories')
    plt.xticks(rotation=45)

    plt.subplot(2, 2, 4)
    plt.bar(categories, max_values, color='lightcoral')
    plt.xlabel('Tumor Categories')
    plt.ylabel('Maximum Pixel Value')
    plt.title('Maximum Pixel Value Across Tumor Categories')
    plt.xticks(rotation=45)

    plt.tight_layout()
    plt.show()

# Set the dataset directory
dataset_dir = 'cleaned/Training'

# Calculate statistics
stats = calculate_image_statistics(dataset_dir)

# Print the calculated statistics for debugging
for category, stat in stats.items():
    print(f"Category: {category}")
    print(f"Mean Pixel Value: {stat['mean']}")
    print(f"Standard Deviation of Pixel Values: {stat['std_dev']}")
    print(f"Minimum Pixel Value: {stat['min_value']}")
    print(f"Maximum Pixel Value: {stat['max_value']}")
    print()

# Plot the statistics graphically
plot_statistics(stats)
# Out:
# Category: glioma
# Mean Pixel Value: 56.28941563527572
# Standard Deviation of Pixel Values: 35.90628528686301
# Minimum Pixel Value: 0
# Maximum Pixel Value: 255
#
# Category: pituitary
# Mean Pixel Value: 61.949515893186046
# Standard Deviation of Pixel Values: 37.953422958466774
# Minimum Pixel Value: 0
# Maximum Pixel Value: 255
#
# Category: meningioma
# Mean Pixel Value: 68.57615028022384
# Standard Deviation of Pixel Values: 44.77550894696511
# Minimum Pixel Value: 0
# Maximum Pixel Value: 255
#
# Category: notumor
# Mean Pixel Value: 89.77823929263506
# Standard Deviation of Pixel Values: 54.12784684816836
# Minimum Pixel Value: 0
# Maximum Pixel Value: 255
#
# Minimum values: [0, 0, 0, 0]

# %%
def calculate_image_quality_metrics(img_path):
    """
    Calculates image quality metrics including sharpness, contrast, and brightness.

    Parameters:
    img_path (str): Path to the image file.

    Returns:
    dict: Dictionary containing image quality metrics.
    """
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Read image as grayscale
    if img is None:
        raise ValueError(f"Unable to read image: {img_path}")

    # Calculate sharpness (high frequency conten means detects edges)
    laplacian_var = cv2.Laplacian(img, cv2.CV_64F).var()
    sharpness = laplacian_var

    # Calculate contrast (pixel intensity range or spread of pixels)
    contrast = np.std(img)

    # Calculate brightness (mean pixel value)
    brightness = np.mean(img)

    metrics = {
        'sharpness': sharpness,
        'contrast': contrast,
        'brightness': brightness
    }

    return metrics

def analyze_image_quality(dataset_dir):
    """
    Analyzes image quality metrics (sharpness, contrast, brightness) for images in a dataset directory.

    Parameters:
    dataset_dir (str): Directory containing image files.

    Returns:
    dict: Dictionary containing image quality metrics for each image file.
    """
    sharpness_values = []
    contrast_values = []
    brightness_values = []

    for category in os.listdir(dataset_dir):
        category_path = os.path.join(dataset_dir, category)
        if os.path.isdir(category_path):
            for img_name in os.listdir(category_path):
                img_path = os.path.join(category_path, img_name)
                try:
                    metrics = calculate_image_quality_metrics(img_path)
                    sharpness_values.append(metrics['sharpness'])
                    contrast_values.append(metrics['contrast'])
                    brightness_values.append(metrics['brightness'])
                except Exception as e:
                    print(f"Error processing {img_path}: {str(e)}")

    return sharpness_values, contrast_values, brightness_values


dataset_dir = 'cleaned/Training'  # Replace with your dataset directory
sharpness_values, contrast_values, brightness_values = analyze_image_quality(dataset_dir)

# Plotting
plt.figure(figsize=(8, 4))

# Plot sharpness
plt.subplot(1, 3, 1)
plt.hist(sharpness_values, bins=20, color='skyblue', edgecolor='black')
plt.title('Sharpness Distribution')
plt.xlabel('Sharpness')
plt.ylabel('Number of Images')

# Plot contrast
plt.subplot(1, 3, 2)
plt.hist(contrast_values, bins=20, color='green', edgecolor='black')
plt.title('Contrast Distribution')
plt.xlabel('Contrast')
plt.ylabel('Number of Images')

# Plot brightness
plt.subplot(1, 3, 3)
plt.hist(brightness_values, bins=20, color='orange', edgecolor='black')
plt.title('Brightness Distribution')
plt.xlabel('Brightness')
plt.ylabel('Number of Images')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Applying under-sampling technique:
# exploratory data analysis (EDA) reveals that the "no tumor" category has more images compared to the other categories (pituitary, meningioma, and glioma), it could potentially impact the training and performance of machine learning model, so to metigate this error undersampling technique is used. Undersampling is a technique used to balance class distribution by reducing the number of instances in the majority class(es) to match the minority class.

# %%
def undersample_dataset(input_dir, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    categories = os.listdir(input_dir)
    num_samples_per_class = None

    # Find the category with the fewest images (assumed as the minority class)
    for category in categories:
        category_path = os.path.join(input_dir, category)
        if os.path.isdir(category_path):
            num_images = len(os.listdir(category_path))
            if num_samples_per_class is None or num_images < num_samples_per_class:
                num_samples_per_class = num_images

    # Undersample each category to match num_samples_per_class
    for category in categories:
        category_path = os.path.join(input_dir, category)
        output_category_path = os.path.join(output_dir, category)

        if os.path.isdir(category_path):
            if not os.path.exists(output_category_path):
                os.makedirs(output_category_path)

            image_list = os.listdir(category_path)
            random.shuffle(image_list)  # Shuffle images for random selection

            for img_name in image_list[:num_samples_per_class]:
                src_path = os.path.join(category_path, img_name)
                dst_path = os.path.join(output_category_path, img_name)
                shutil.copy(src_path, dst_path)


input_dir = 'cleaned/Training'
output_dir = 'balanced_dataset/Training'  # Directory to store undersampled dataset

undersample_dataset(input_dir, output_dir)

# %%
#simply calling the class distribution plot function to visualise the classes samples after
#applying under sampling technique

plot_class_distribution(output_dir)

# %% [markdown]
# # **Crerating Model EDN-SVM (Ensemble Deep Neural Support Vector Machine):**
# To apply the Ensemble Deep Neural Support Vector Machine (EDSVM) algorithm to preprocessed or cleaned dataset, we'll need to integrate both a deep neural network (DNN) and a support vector machine (SVM) into a cohesive model.and then we have to ensemble the predictions, also we can record the working of these two models as a standalone aswell.

# %%
train_dir = 'balanced_dataset/Training'
test_dir = 'cleaned/Testing'

# Image data generators for training and testing datasets
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 5284 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %% [markdown]
# **Defining the DEEP NEURAL NETWORK MODEL:**
# It will serve as a feature extractor

# %%
def create_cnn_model(input_shape=(256, 256, 3)):
    """
    Creates and returns a Convolutional Neural Network (CNN) model using the Keras Sequential API.

    Parameters:
    input_shape (tuple): The shape of the input data (height, width, channels). Default is (256, 256, 3).

    Returns:
    model (Sequential): A Keras Sequential model representing the CNN.
    """
    model = Sequential()  # Initialize the Sequential model

    # Add an Input layer with the shape of the input data
    model.add(Input(shape=input_shape))

    # Add the first convolutional layer with 32 filters and a 3x3 kernel, ReLU activation
    model.add(Conv2D(32, (3, 3), activation='relu'))
    # Add a max pooling layer with a 2x2 pool size
    model.add(MaxPooling2D((2, 2)))

    # Add the second convolutional layer with 64 filters and a 3x3 kernel, followed by a max pooling layer
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))

    # Add the third convolutional layer with 128 filters and a 3x3 kernel, followed by a max pooling layer
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))

    # Flatten the output of the previous layer to create a 1D feature vector
    model.add(Flatten())

    # Add a fully connected (dense) layer with 128 units and ReLU activation
    model.add(Dense(128, activation='relu'))

    # Add a dropout layer with a rate of 0.5 to prevent overfitting
    model.add(Dropout(0.5)) #REGULARIZATION technique

    # Add the output layer with 4 units (one for each class) and softmax activation for classification
    model.add(Dense(4, activation='softmax'))

    # Compile the model with the Adam optimizer, categorical crossentropy loss function, and accuracy metric
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# Create an instance of the CNN model
cnn_model = create_cnn_model()
cnn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 62, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 60, 60, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 30, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 115200)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │      14,745,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │             516 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,839,492 (56.61 MB)
#  Trainable params: 14,839,492 (56.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 20


early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history = cnn_model.fit(
    train_generator,
    epochs=epochs,
    validation_data=test_generator,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 32s 130ms/step - accuracy: 0.5284 - loss: 1.1094 - val_accuracy: 0.7674 - val_loss: 0.5747
# Epoch 2/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 27s 94ms/step - accuracy: 0.8020 - loss: 0.5161 - val_accuracy: 0.8421 - val_loss: 0.4104
# Epoch 3/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - accuracy: 0.8686 - loss: 0.3544 - val_accuracy: 0.8650 - val_loss: 0.3535
# Epoch 4/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 14s 85ms/step - accuracy: 0.9073 - loss: 0.2373 - val_accuracy: 0.8574 - val_loss: 0.3946
# Epoch 5/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 20s 84ms/step - accuracy: 0.9391 - loss: 0.1783 - val_accuracy: 0.8955 - val_loss: 0.3198
# Epoch 6/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 21s 86ms/step - accuracy: 0.9503 - loss: 0.1387 - val_accuracy: 0.9161 - val_loss: 0.2676
# Epoch 7/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.9653 - loss: 0.0935 - val_accuracy: 0.9268 - val_loss: 0.2368
# Epoch 8/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 20s 83ms/step - accuracy: 0.9734 - loss: 0.0755 - val_accuracy: 0.9260 - val_loss: 0.2825
# Epoch 9/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - accuracy: 0.9792 - loss: 0.0662 - val_accuracy: 0.9146 - val_loss: 0.3108
# Epoch 10/20
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 16s 93ms/step - accuracy: 0.9773 - loss: 0.0616 - val_accuracy: 0.9359 - val_loss: 0.2460

# %%
# Plotting training and validation accuracy and loss

def plot_training_history(history):
    """
    Plots the training and validation accuracy and loss over epochs.

    Parameters:
    history (History object): History object returned by the fit method of the model.
    """
    # Extract the accuracy and loss values for training and validation
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    # Plot training and validation accuracy
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'b', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'b', label='Training Loss')
    plt.plot(epochs, val_loss, 'r', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
# Plot the training history
plot_training_history(history)

# %% [markdown]
# **Extracting Features from trained CNN**

# %%
# Function to extract features using the CNN
def extract_features(model, generator):
    features = []
    labels = []
    for inputs, targets in generator:
        features_batch = model.predict(inputs)
        features.append(features_batch)
        labels.append(targets)
        if len(features) * generator.batch_size >= generator.samples:
            break

    features = np.vstack(features)
    labels = np.vstack(labels)
    return features, labels

# Remove the last layer of the CNN to get features
#creates a seperate model  this time with feature vectors
feature_extractor = Sequential(cnn_model.layers[:-1])

train_features, train_labels = extract_features(feature_extractor, train_generator)
test_features, test_labels = extract_features(feature_extractor, test_generator)

# Convert labels from one-hot encoding to integers
train_labels = np.argmax(train_labels, axis=1)
test_labels = np.argmax(test_labels, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 576ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step

# %%
from sklearn.manifold import TSNE  # Importing the TSNE module from scikit-learn for dimensionality reduction

# Apply t-SNE to reduce dimensions to 2D for visualization
tsne = TSNE(n_components=2, random_state=0)  # Initialize t-SNE with 2 components and a fixed random state for reproducibility

train_features_2d = tsne.fit_transform(train_features)  # Transform the training features to 2D space
test_features_2d = tsne.fit_transform(test_features)    # Transform the test features to 2D space

# Create a figure with two subplots to visualize the 2D embeddings
plt.figure(figsize=(12, 6))  # Set the figure size for the plots

# Plot the 2D embedding of training features
plt.subplot(1, 2, 1)  # Create the first subplot in a 1x2 grid
plt.scatter(train_features_2d[:, 0], train_features_2d[:, 1], c=train_labels, cmap='viridis', alpha=0.5)  # Scatter plot of the training features, colored by labels
plt.colorbar()  # Add a colorbar to show the label mapping
plt.title('Train Features (t-SNE)')  # Set the title for the training features plot

# Plot the 2D embedding of test features
plt.subplot(1, 2, 2)  # Create the second subplot in a 1x2 grid
plt.scatter(test_features_2d[:, 0], test_features_2d[:, 1], c=test_labels, cmap='viridis', alpha=0.5)  # Scatter plot of the test features, colored by labels
plt.colorbar()  # Add a colorbar to show the label mapping
plt.title('Test Features (t-SNE)')  # Set the title for the test features plot

plt.show()  # Display the plots

# %% [markdown]
# **training SVM on extracted features**

# %%
# Create and train the SVM model

# Create an SVM model pipeline
# The pipeline includes a StandardScaler for normalization and an SVC with a linear kernel
svm_model = make_pipeline(StandardScaler(), SVC(kernel='linear', probability=True))

# Fit the SVM model on the training data
# train_features: The feature vectors extracted from the training images
# train_labels: The corresponding labels for the training images
svm_model.fit(train_features, train_labels)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(kernel='linear', probability=True))])

# %%
def plot_confusion_matrix(y_true, y_pred, classes, title='Confusion Matrix'):
    """
    Plots a confusion matrix using true and predicted labels.

    Parameters:
    y_true (array-like): True labels.
    y_pred (array-like): Predicted labels.
    classes (list): List of class names.
    title (str): Title of the confusion matrix plot.
    """
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# Define class names
class_names = list(train_generator.class_indices.keys())

# %%
# Predict using the SVM model
test_predictions = svm_model.predict(test_features)

# Evaluate the predictions
print("Classification Report:")
print(classification_report(test_labels, test_predictions))
print("Accuracy:", accuracy_score(test_labels, test_predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       300
#            1       0.88      0.90      0.89       306
#            2       0.99      0.99      0.99       405
#            3       0.94      0.95      0.95       300
#
#     accuracy                           0.94      1311
#    macro avg       0.93      0.93      0.93      1311
# weighted avg       0.94      0.94      0.94      1311
#
# Accuracy: 0.9374523264683448

# %%
#Plotting the confusion matrix for SVM
plot_confusion_matrix(test_labels, test_predictions, class_names, title='Confusion Matrix for SVM')

# %% [markdown]
# **Ensembling CNN with SVM to make it EDN-SVM:**
#
# This model that combines the predictions from both the CNN and the SVM for better performance. It integrates a CNN for feature extraction and an SVM for classification, utilizing the strengths of both techniques. The ensemble approach at the end aims to further improve classification performance.

# %%
def ensemble_predict(cnn_model, svm_model, test_generator):
    cnn_predictions = cnn_model.predict(test_generator)
    svm_predictions = svm_model.predict_proba(test_features)

    final_predictions = (cnn_predictions + svm_predictions) / 2
    return np.argmax(final_predictions, axis=1)

ensemble_predictions = ensemble_predict(cnn_model, svm_model, test_generator)

# Evaluate the ensemble model
print("Ensemble Classification Report:")
print(classification_report(test_labels, ensemble_predictions))
print("Ensemble Accuracy:", accuracy_score(test_labels, ensemble_predictions))
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step
# Ensemble Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       300
#            1       0.89      0.90      0.89       306
#            2       0.99      0.99      0.99       405
#            3       0.94      0.95      0.94       300
#
#     accuracy                           0.94      1311
#    macro avg       0.93      0.93      0.93      1311
# weighted avg       0.94      0.94      0.94      1311
#
# Ensemble Accuracy: 0.9359267734553776

# %%
# Plot confusion matrix for ensemble model
plot_confusion_matrix(test_labels, ensemble_predictions, class_names, title='Confusion Matrix for Ensemble Model')

# %%
# Binarize the labels for ROC curve computation
test_labels_bin = label_binarize(test_labels, classes=[0, 1, 2, 3])

# svm_predictions_prob and cnn_model.predict(test_generator) are already computed
svm_predictions_prob = svm_model.predict_proba(test_features)
ensemble_predictions_prob = (cnn_model.predict(test_generator) + svm_predictions_prob) / 2

# Plot ROC curves for each class for Ensemble model
plt.figure(figsize=(8, 6))  # figure size
for i in range(4):
    fpr, tpr, _ = roc_curve(test_labels_bin[:, i], ensemble_predictions_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Ensemble ROC curve (class {i}) (area = {roc_auc:.2f})')
    plt.fill_between(fpr, tpr, alpha=0.2)

# Plot random classifier baseline
plt.plot([0, 1], [0, 1], 'k--', lw=2)  # Add a dashed line for random classifier

# Gridlines
plt.grid(True)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Ensemble ROC Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step

# %%
def visualize_predictions(generator, true_labels, predictions, categories, n=5):
    """
    Visualize random sample images with their true and predicted labels.

    Parameters:
    generator (DirectoryIterator): Keras DirectoryIterator for the dataset.
    true_labels (array-like): Array of true labels.
    predictions (array-like): Array of predicted labels.
    categories (list): List of category names.
    n (int): Number of images to display per category. Default is 5.
    """
    # Get the image file paths and labels from the generator
    file_paths = generator.filepaths
    label_map = {v: k for k, v in generator.class_indices.items()}

    plt.figure(figsize=(15, 15))

    for class_idx, class_name in enumerate(categories):
        # Get indices of images belonging to the current class
        class_indices = np.where(true_labels == class_idx)[0]
        # Select random sample of indices
        sample_indices = random.sample(list(class_indices), n)

        for i, idx in enumerate(sample_indices):
            img_path = file_paths[idx]
            true_label = label_map[true_labels[idx]]
            predicted_label = label_map[predictions[idx]]

            # Load the image
            img = Image.open(img_path)

            ax = plt.subplot(len(categories), n, class_idx * n + i + 1)
            plt.imshow(img)
            title_color = 'green' if true_label == predicted_label else 'red'
            plt.title(f"True: {true_label}\nPred: {predicted_label}", color=title_color)
            plt.axis('off')

    plt.tight_layout()
    plt.show()

# test_labels is already an array of integers
# Generate ensemble predictions
ensemble_predictions = ensemble_predict(cnn_model, svm_model, test_generator)

# Visualize the predictions
visualize_predictions(test_generator, test_labels, ensemble_predictions, class_names)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step

# %%
# Comparison bar chart for accuracy
models = ['CNN', 'SVM', 'Ensemble']
accuracies = [accuracy_score(test_labels, np.argmax(cnn_model.predict(test_generator), axis=1)),
              accuracy_score(test_labels, test_predictions),
              accuracy_score(test_labels, ensemble_predictions)]

plt.figure(figsize=(6, 4))
plt.bar(models, accuracies, color=['blue', 'green', 'red'])
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Model Accuracy Comparison')
plt.ylim([0, 1])
plt.show()
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step

# %% [markdown]
# # **Comparative Analysis of Research Articles with Model**
# a bar graph was created using python and matplotlib skills to add it in the report, so thats why added this additionally.

# %%
# Data for the bar graph
papers = [
    "Rao et al. (2015)",
    "Gunasekara et al. (2021)",
    "Amin et al. (2018)",
    "Sriramakrishnan (2019)",
    "Abd-Ellah et al. (2018)",
    "A B Malarvizhi et al. (2022)",
    "Our Ensemble Model"
]
accuracies = [67, 94, 99.8, 94.3, 98.71, 87, 94]

# Plotting the bar graph
plt.figure(figsize=(8, 6))
plt.bar(papers, accuracies, color=['blue', 'orange', 'green', 'red', 'purple', 'brown', 'cyan'])
plt.xlabel('Papers')
plt.ylabel('Accuracy (%)')
plt.title('Comparative Accuracy of Brain Tumor Classification Models')
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 100)

# Display the plot
plt.tight_layout()
plt.show()
